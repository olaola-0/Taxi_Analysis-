# %%
import pandas as pd

# %%
from src.paths import TAXI_ZONES_DIR

# %%
df = pd.read_parquet(TAXI_ZONES_DIR/'taxi_zones_df.parquet')
df
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
#            borough   Latitude  Longitude
# 0              EWR  40.691830 -74.174002
# 1           Queens  40.616746 -73.831300
# 2            Bronx  40.864474 -73.847422
# 3        Manhattan  40.723752 -73.976968
# 4    Staten Island  40.552659 -74.188485
# ..             ...        ...        ...
# 258          Bronx  40.897932 -73.852215
# 259         Queens  40.744234 -73.906307
# 260      Manhattan  40.709139 -74.013023
# 261      Manhattan  40.775932 -73.946510
# 262      Manhattan  40.778766 -73.951010
#
# [263 rows x 8 columns]

# %%
print(df.columns)
# Out:
# Index(['OBJECTID', 'Shape_Leng', 'Shape_Area', 'zone', 'LocationID', 'borough',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
import folium

# Creating a map centered around NYC
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Adding markers for each taxi zone
for idx, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"LocationID: {row['LocationID']}, Zone: {row['zone']}, Borough: {row['borough']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(nyc_map)

# %%
from IPython.display import display
display(nyc_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084a5f3702968ab23d2597ddeca758cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084a5f3702968ab23d2597ddeca758cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_084a5f3702968ab23d2597ddeca758cb = L.map(
#                 &quot;map_084a5f3702968ab23d2597ddeca758cb&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9608bc98052468499764c05c7a0fa3d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9608bc98052468499764c05c7a0fa3d8.addTo(map_084a5f3702968ab23d2597ddeca758cb);
#
#
#             var marker_1fef2039988a09fa173b242c0161daf8 = L.marker(
#                 [40.69183016020959, -74.17400156582248],
#                 {}
#             ).addTo(map_084a5f3702968ab23d2597ddeca758cb);
#
#
#             var icon_a5d2b9f996c2cf3975fa4e62a6f8d08d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1fef2039988a09fa173b242c0161daf8.setIcon(icon_a5d2b9f996c2cf3975fa4e62a6f8d08d);
#
#
#         var popup_902c51620f783fbb4fba7f0d7518b714 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f494aa1c3222095d4caba531a1543e6c = $(`&lt;div id=&quot;html_f494aa1c3222095d4caba531a1543e6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LocationID: 1, Zone: Newark Airport, Borough: EWR&lt;/div&gt;`)[0];
#                 popup_902c51620f783fbb4fba7f0d7518b714.setContent(html_f494aa1c3222095d4caba531a1543e6c);
#
#
#
#         marker_1fef2039988a09fa173b242c0161daf8.bindPopup(popup_902c51620f783fbb4fba7f0d7518b714)
#         ;
#
#
#
#
#             var marker_2cbeebd5918f8f49a5aad55e8edb2b12 = L.marker(
#                 [40.61674619937379, -73.83129979354713],
#                 {}
#             ).addTo(map_084a5f3702968ab23d2597ddeca758cb);
#
#
#             var icon_7373cf3dad143c27ddede1aebc902930 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2cbeebd5918f8f49a5aad55e8edb2b12.setIcon(icon_7373cf3dad143c27ddede1aebc902930);
#
#
#         var popup_946151691ab32a1c436b6d23cb123b5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a7ed3ba0c669a16acc5a1bccc34bdc4 = $(`&lt;div id=&quot;html_8a7ed3ba0c669a16acc5a1bccc34bdc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LocationID: 2, Zone: Jamaica Bay, Borough: Queens&lt;/div&gt;`)[0];
#                 popup_946151691ab32a1c436b6d23cb123b5e.setContent(html_8a7ed3ba0c669a16acc5a1bccc34bdc4);
#
#
#
#         marker_2cbeebd5918f8f49a5aad55e8edb2b12.bindPopup(popup_946151691ab32a1c436b6d23cb123b5e)
#         ;
#
#
#
#
#             var marker_e2cf200747e0ef44b25647cc10c345b4 = L.marker(
#                 [40.86447372906584, -73.8474217852696],
#                 {}
#             ).addTo(map_084a5f3702968ab23d2597ddeca758cb);
#
#
#             var icon_914d977957a8d2d3d2a398edf7bd8ac4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e2cf200747e0ef44b25647cc10c345b4.setIcon(icon_914d977957a8d2d3d2a398edf7bd8ac4);
#
#
#         var popup_b231a5554cbc4eb59a7f5a44725941ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bec5c41a811c1144f0e3575c8204afb = $(`&lt;div id=&quot;html_6bec5c41a811c1144f0e3575c8204afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LocationID: 3, Zone: Allerton/Pelham Gardens, Borough: Bronx&lt;/div&gt;`)[0];
#                 popup_b231a5554cbc4eb59a7f5a44725941ba.setContent(html_6bec5c41a811c1144f0e3575c8204afb);
#
#
#
#         marker_e2cf200747e0ef44b25647cc10c345b4.bindPopup(popup_b231a5554cbc4eb59a7f5a44725941ba)
#         ;
#
#
#
#
#             var marker_6752092c49b76ed10e731deaa2ec19f5 = L.marker(
#                 [40.72375208451233, -73.97696827424141],
#                 {}
#             ).addTo(map_084a5f3702968ab23d2597ddeca758cb);
#
#
#             var icon_6385ef73bc9730a0218a9145e2ae8d75 = L.A

# %%
# To group the locations by borough and plot them with different colors, we'll adjust the plotting approach.

# First, let's group the dataframe by borough and assign a unique color to each group.
borough_colors = {
    "EWR": "darkred",
    "Queens": "blue",
    "Bronx": "green",
    "Manhattan": "purple",
    "Staten Island": "orange",
    "Brooklyn": "darkblue"
}

# Creating a new map centered around NYC
nyc_map_grouped = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Adding markers, grouped by borough with distinct colors
for idx, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"LocationID: {row['LocationID']}, Zone: {row['zone']}",
        icon=folium.Icon(color=borough_colors.get(row['borough'], 'gray'), icon='info-sign')
    ).add_to(nyc_map_grouped)

# Displaying the map
nyc_map_grouped.save(TAXI_ZONES_DIR/'nyc_taxi_zones_map_grouped.html')

# %%
display(nyc_map_grouped)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_532bf8874084dc7cabb585842d149129 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_532bf8874084dc7cabb585842d149129&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_532bf8874084dc7cabb585842d149129 = L.map(
#                 &quot;map_532bf8874084dc7cabb585842d149129&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b89f0f546b0ed15dc38c4ee5a914980 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5b89f0f546b0ed15dc38c4ee5a914980.addTo(map_532bf8874084dc7cabb585842d149129);
#
#
#             var marker_a5048c92a4f5f6c708672cdf0f627ba5 = L.marker(
#                 [40.69183016020959, -74.17400156582248],
#                 {}
#             ).addTo(map_532bf8874084dc7cabb585842d149129);
#
#
#             var icon_4b7e4b08665207792a8ccd1bec11d63a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a5048c92a4f5f6c708672cdf0f627ba5.setIcon(icon_4b7e4b08665207792a8ccd1bec11d63a);
#
#
#         var popup_add508ee1230099234436b0ad32c7ae4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15cde4a8bacfd23bddbabe6430e04ea3 = $(`&lt;div id=&quot;html_15cde4a8bacfd23bddbabe6430e04ea3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LocationID: 1, Zone: Newark Airport&lt;/div&gt;`)[0];
#                 popup_add508ee1230099234436b0ad32c7ae4.setContent(html_15cde4a8bacfd23bddbabe6430e04ea3);
#
#
#
#         marker_a5048c92a4f5f6c708672cdf0f627ba5.bindPopup(popup_add508ee1230099234436b0ad32c7ae4)
#         ;
#
#
#
#
#             var marker_1000a9a0d7d0bc8db26ad0323153d8dc = L.marker(
#                 [40.61674619937379, -73.83129979354713],
#                 {}
#             ).addTo(map_532bf8874084dc7cabb585842d149129);
#
#
#             var icon_a42e849ded2c9d07cda05a5ab202867c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1000a9a0d7d0bc8db26ad0323153d8dc.setIcon(icon_a42e849ded2c9d07cda05a5ab202867c);
#
#
#         var popup_f748e5ed52dcd6fe44186ca47c04dbca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e88715effcafb0fe5ef3aa7c2b8744e = $(`&lt;div id=&quot;html_2e88715effcafb0fe5ef3aa7c2b8744e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LocationID: 2, Zone: Jamaica Bay&lt;/div&gt;`)[0];
#                 popup_f748e5ed52dcd6fe44186ca47c04dbca.setContent(html_2e88715effcafb0fe5ef3aa7c2b8744e);
#
#
#
#         marker_1000a9a0d7d0bc8db26ad0323153d8dc.bindPopup(popup_f748e5ed52dcd6fe44186ca47c04dbca)
#         ;
#
#
#
#
#             var marker_47f3f2a110f5e03d06e584b29c951b2d = L.marker(
#                 [40.86447372906584, -73.8474217852696],
#                 {}
#             ).addTo(map_532bf8874084dc7cabb585842d149129);
#
#
#             var icon_81130746d299791d27182292fe5ddafe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47f3f2a110f5e03d06e584b29c951b2d.setIcon(icon_81130746d299791d27182292fe5ddafe);
#
#
#         var popup_061055356fb8dc1c5acdf1ae9be3dafc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b4fe67cef89d3a7bf9e7542f7beaded = $(`&lt;div id=&quot;html_8b4fe67cef89d3a7bf9e7542f7beaded&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LocationID: 3, Zone: Allerton/Pelham Gardens&lt;/div&gt;`)[0];
#                 popup_061055356fb8dc1c5acdf1ae9be3dafc.setContent(html_8b4fe67cef89d3a7bf9e7542f7beaded);
#
#
#
#         marker_47f3f2a110f5e03d06e584b29c951b2d.bindPopup(popup_061055356fb8dc1c5acdf1ae9be3dafc)
#         ;
#
#
#
#
#             var marker_a26da718798561fabd8d37d67871d011 = L.marker(
#                 [40.72375208451233, -73.97696827424141],
#                 {}
#             ).addTo(map_532bf8874084dc7cabb585842d149129);
#
#
#             var icon_006b52bb5bf9e35cd88c61a9122552e9 = L.AwesomeMarkers.icon(
#                 {&quot;

# %%
# Calculate mean coordinates for each borough to find the centroid
borough_means = df.groupby('borough')[['Latitude', 'Longitude']].mean()

# Define colors for each borough (optional, you can customize this)
borough_colors = {
    "EWR": "darkred",
    "Queens": "blue",
    "Bronx": "green",
    "Manhattan": "purple",
    "Staten Island": "orange",
    "Brooklyn": "darkblue"
}

# Create a new map centered around NYC
nyc_map_borough_names_auto = folium.Map(location=[40.7128, -74.0060], zoom_start=10)

# Add markers for each borough's centroid with auto-opening popups
for borough, row in borough_means.iterrows():
    popup_content = folium.Popup(borough, show=True)
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_content,
        icon=folium.Icon(color=borough_colors.get(borough, 'gray'), icon='info-sign')
    ).add_to(nyc_map_borough_names_auto)

# %%
display(nyc_map_borough_names_auto)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ec2601b7e656ce8c470d4248d798b7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ec2601b7e656ce8c470d4248d798b7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ec2601b7e656ce8c470d4248d798b7e = L.map(
#                 &quot;map_8ec2601b7e656ce8c470d4248d798b7e&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ffab98c0d31b020b771ee3e7a5ffd08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9ffab98c0d31b020b771ee3e7a5ffd08.addTo(map_8ec2601b7e656ce8c470d4248d798b7e);
#
#
#             var marker_bf70227e8495e55d62da85b917c85774 = L.marker(
#                 [40.84926994224912, -73.87556728662406],
#                 {}
#             ).addTo(map_8ec2601b7e656ce8c470d4248d798b7e);
#
#
#             var icon_aa6a1020d8a1d0bcb251f82263c31a87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf70227e8495e55d62da85b917c85774.setIcon(icon_aa6a1020d8a1d0bcb251f82263c31a87);
#
#
#         var popup_8634f2858460cd3d4075fa1473841c5a = L.popup({&quot;autoClose&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a47a9623c86b726e4a4387efb023f924 = $(`&lt;div id=&quot;html_a47a9623c86b726e4a4387efb023f924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_8634f2858460cd3d4075fa1473841c5a.setContent(html_a47a9623c86b726e4a4387efb023f924);
#
#
#
#         marker_bf70227e8495e55d62da85b917c85774.bindPopup(popup_8634f2858460cd3d4075fa1473841c5a)
#         .openPopup();
#
#
#
#
#             var marker_6e2eae88c8d2c129dd1e86002c1440cd = L.marker(
#                 [40.65528261359505, -73.95909716262787],
#                 {}
#             ).addTo(map_8ec2601b7e656ce8c470d4248d798b7e);
#
#
#             var icon_f497e48fc5b84918f84e7e27ab8f38ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6e2eae88c8d2c129dd1e86002c1440cd.setIcon(icon_f497e48fc5b84918f84e7e27ab8f38ad);
#
#
#         var popup_6a7a8d6ec226e54fedd238082baa0d47 = L.popup({&quot;autoClose&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cfe91cdea567945f9cb4e380fad6c46 = $(`&lt;div id=&quot;html_1cfe91cdea567945f9cb4e380fad6c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#                 popup_6a7a8d6ec226e54fedd238082baa0d47.setContent(html_1cfe91cdea567945f9cb4e380fad6c46);
#
#
#
#         marker_6e2eae88c8d2c129dd1e86002c1440cd.bindPopup(popup_6a7a8d6ec226e54fedd238082baa0d47)
#         .openPopup();
#
#
#
#
#             var marker_c97fb18825000be13349229b0b3d1d7a = L.marker(
#                 [40.69183016020959, -74.17400156582248],
#                 {}
#             ).addTo(map_8ec2601b7e656ce8c470d4248d798b7e);
#
#
#             var icon_efa9fa6ab3460fef87bf1012692fd276 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c97fb18825000be13349229b0b3d1d7a.setIcon(icon_efa9fa6ab3460fef87bf1012692fd276);
#
#
#         var popup_a97e16e6ee70be1df97eabb5385e2337 = L.popup({&quot;autoClose&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee6ab9fad9739f31ea541fefdb857deb = $(`&lt;div id=&quot;html_ee6ab9fad9739f31ea541fefdb857deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EWR&lt;/div&gt;`)[0];
#                 popup_a97e16e6ee70be1df97eabb5385e2337.setContent(html_ee6ab9fad9739f31ea541fefdb857deb);
#
#
#
#         marker_c97fb18825000be13349229b0b3d1d7a.bindPopup(popup_a97e16e6ee70be1df97eabb5385e2337)
#         .openPopup();
#
#
#
#
#             var marker_ba6b38215e415b43e64c8bf32165a107 = L.marker(
#                 [40.76116730013686, -73.97808940088582],
#                 {}
#             ).addTo(map_8ec2601b7e656ce8c470d4248d798b7e);
#
#
#             var icon_95705d8425f183caf4ae9f7267c25212 = L.AwesomeM

# %%
nyc_map_borough_names_auto.save(TAXI_ZONES_DIR/'nyc_taxi_zones_borough_names.html')
